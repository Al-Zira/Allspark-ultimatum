# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
os.environ["GOOGLE_API_KEY"]
# Out:
# 'AIzaSyBsATgW0xI0cngZ01zn9KGAnqTFzPPeA7A'

# %%
pip install pinecone
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3.10 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# import form
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
import  pinecone
from langchain.document_loaders import PyPDFLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import ctransformers
import os

from langchain.llms import CTransformers
# from langchain_google_genai import ChatGoogleGenerativeAI
import google.generativeai as genai
from langchain_core.messages import HumanMessage,AIMessage

# %%
from langchain_google_genai import GoogleGenerativeAI

# %%
llm = GoogleGenerativeAI(model='gemini-pro', temperature=0.9, api_key=os.environ["GOOGLE_API_KEY"])

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# "J'aime la programmation."

# %%
ai_msg.content
# Out:
# "J'adore programmer. \n"

# %%
pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import PyPDFLoader,DirectoryLoader

# %%
#Extract data from the PDF
def load_pdf(data):
    loader = DirectoryLoader(data,
                    glob="*.pdf",
                    loader_cls=PyPDFLoader)

    documents = loader.load()

    return documents

# %%
extracted_data = load_pdf("/Users/harshshivhare/ALLSPARK/Harsh/Conversational Data Query Assistant")

# %%
extracted_data
# Out:
# [Document(metadata={'source': '/Users/harshshivhare/ALLSPARK/Harsh/Conversational Data Query Assistant/data science interview preparation guide.pdf', 'page': 0}, page_content='N I T I N  M U K E S H\nRevised Edition'),
#  Document(metadata={'source': '/Users/harshshivhare/ALLSPARK/Harsh/Conversational Data Query Assistant/data science interview preparation guide.pdf', 'page': 1}, page_content='© 2021 Nitin Mukesh\nAll rights reserved. No portion of this book may be\nreproduced in any form without permission from the\nAuthor. \nRevised First Edition'),
# ...

# %%
pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
extracted_data
# Out:
# [Document(metadata={'source': '/Users/harshshivhare/ALLSPARK/Harsh/Conversational Data Query Assistant/data science interview preparation guide.pdf', 'page': 0}, page_content='N I T I N  M U K E S H\nRevised Edition'),
#  Document(metadata={'source': '/Users/harshshivhare/ALLSPARK/Harsh/Conversational Data Query Assistant/data science interview preparation guide.pdf', 'page': 1}, page_content='© 2021 Nitin Mukesh\nAll rights reserved. No portion of this book may be\nreproduced in any form without permission from the\nAuthor. \nRevised First Edition'),
# ...

# %%
#Create text chunks
def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 20)
    text_chunks = text_splitter.split_documents(extracted_data)

    return text_chunks

# %%
text_chunks=text_split(extracted_data)

# %%
len(text_chunks)
# Out:
# 180

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.getenv('HUGGINNGFACEHUB_API_TOKEN')

# %%
def huggingface_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    return embeddings

# %%
embeddings = huggingface_embeddings()
# Out:
# /var/folders/r_/bwm16vxs3rzd8dfvb8s0507w0000gn/T/ipykernel_20318/3972333992.py:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

# %%
text_chunks
# Out:
# [Document(metadata={'source': '/Users/harshshivhare/ALLSPARK/Harsh/Conversational Data Query Assistant/data science interview preparation guide.pdf', 'page': 0}, page_content='N I T I N  M U K E S H\nRevised Edition'),
#  Document(metadata={'source': '/Users/harshshivhare/ALLSPARK/Harsh/Conversational Data Query Assistant/data science interview preparation guide.pdf', 'page': 1}, page_content='© 2021 Nitin Mukesh\nAll rights reserved. No portion of this book may be\nreproduced in any form without permission from the\nAuthor. \nRevised First Edition'),
# ...

# %%
from pinecone import Pinecone

pc = Pinecone(api_key="97b58164-1042-4a9a-ba02-fd29b9a3e6df")
index = pc.Index("aizira")

# %%
index

# %%
import os
from pinecone import Pinecone
from langchain.vectorstores import Pinecone as PineconeStore

# Set the Pinecone API key as an environment variable
os.environ["PINECONE_API_KEY"] = "97b58164-1042-4a9a-ba02-fd29b9a3e6df"

# You may not need to create a Pinecone instance explicitly here anymore,
# as the PineconeStore will now use the environment variable.
# pc = Pinecone(api_key="97b58164-1042-4a9a-ba02-fd29b9a3e6df")
# index = pc.Index("rag")

docsearch = PineconeStore.from_texts(
    texts=[t.page_content for t in text_chunks],
    embedding=embeddings,
    index_name="aizira",  # Make sure this index name exists in your Pinecone environment
)

# %%
prompt = """
    You are a Conversational Data Query Assistant, designed to help users extract and analyze specific information 
    from datasets or logs based on provided context. 
    The input will contain context, and your job is to understand the query, interpret the context, and 
    respond with the most relevant data or insights.


    Your primary task is to provide the most accurate, useful, and contextually relevant information from the
    provided input, 
    ensuring that the response addresses the query as precisely as possible.
    """

# %%
from langchain_core.prompts import PromptTemplate, MessagesPlaceholder

PROMPT=PromptTemplate(template=prompt, input_variables=["context", "question"])
chain_type_kwargs={"prompt": PROMPT}

# %%
retriever=docsearch.as_retriever(search_kwargs={'k': 2})

# %%
retriever=docsearch.as_retriever(search_kwargs={'k': 2})

# %%
# from langchain_core.runnables import RunnablePassthrough
retriever_chain = RunnablePassthrough.assign(context=contextualized_question | retriever) #|format_docs)

# %%
# rag_chain = (
#     retriever_chain
#     |qa_prompt
#     | llm
# )

# %%
question = "What is SQL"

# %%
# prompt_template='''Use the following pieces of information to answer the user's question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.

# Context: {context}
# Question: {question}

# Only return the helpful answer below and nothing else.
# Helpful answer:
'''

# %%
PROMPT=PromptTemplate(template=prompt, input_variables=["context", "question"])
chain_type_kwargs={"prompt": PROMPT}

# %%
# memory = ConversationBufferMemory(memory_key="chat_history", output_key='result')

from langchain.chains import ConversationalRetrievalChain

# %%
from langchain.chains.question_answering import load_qa_chain
chain = load_qa_chain(llm, chain_type="stuff", prompt=prompt)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[53], line 2
#       1 from langchain.chains.question_answering import load_qa_chain
# ----> 2 chain = load_qa_chain(llm, chain_type="stuff", prompt=prompt)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/chains/question_answering/chain.py:265, in load_qa_chain(llm, chain_type, verbose, callback_manager, **kwargs)
#     260 if chain_type not in loader_mapping:
#     261     raise ValueError(
#     262         f"Got unsupported chain type: {chain_type}. "
# ...

# %%
qa=ConversationalRetrievalChain.from_llm(
    llm=llm,
    chain_type="stuff",
    retriever=docsearch.as_retriever(search_kwargs={'k': 2}),
    return_source_documents=True
    # chain_type_kwargs=chain_type_kwargs
    )

# %%
while True:
    user_input=input(f"Input Prompt:")
    # ai_msg =rag_chain.invoke({"question": question, "chat_history": chat_history})
    chat_history.extend( [HumanMessage(content=question), ai_msg])
    # result=  qa({"query": user_input})['result']
    result = qa.invoke({"question": user_input, "chat_history": chat_history})
    # chat_history.append((user_input, result["answer"]))
    # return result["answer"]
    print("Response : ", result['answer'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 6
#       2 user_input=input(f"Input Prompt:")
#       3 # ai_msg =rag_chain.invoke({"question": question, "chat_history": chat_history})
#       4 # chat_history.extend( [HumanMessage(content=question), ai_msg])
#       5 # result=  qa({"query": user_input})['result']
# ----> 6 result = qa.invoke({"question": user_input})
#       7 # chat_history.append((user_input, result["answer"]))
#       8 # return result["answer"]
#       9 print("Response : ", result['answer'])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/chains/base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# ...
